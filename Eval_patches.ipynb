# %%
import h5py
f = h5py.File("/Users/dng/Python Projects/PatchMaskExtractor/TestFiles/Patches 2019y07m03d 10h22m32s.hdf5",'r')

# %%
for key in f.keys():
    print(key)
# Out:
# 6-1162-1 DLBCL.svs_Region_(1.00,13633,14600,1884,2231).png
# 6-1162-1 DLBCL.svs_Region_(1.00,17521,10596,873,775).png
# 6-1162-1 DLBCL.svs_Region_(1.00,5065,22026,1034,885).png
# 6-1162-1 DLBCL.svs_Region_(1.00,8410,7168,886,763).png
# 6-1162-1 DLBCL.svs_Region_(1.00,8956,26614,539,620).png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for key in f.keys():
    fig = plt.figure(figsize=(16,8))
    fig.suptitle(key)
    for i in range(8):
        plt.subplot(2,4,i+1)
        plt.imshow(f[key][i,:,:,:])

# %%
f[key].shape
# Out:
# (19, 128, 128, 3)
